# %%
import sqlite3 as sql
import pandas as pd

# %%
conn = sql.connect('factbook.db')
conn

# %%
def sql_query(q):
    return pd.read_sql_query(q,conn)

# %%
q  = '''select * from sqlite_master '''
sql_query(q)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
# 2  table           cities           cities         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...
# 2  CREATE TABLE cities (\n        id integer prim...

# %% [markdown]
# ## Q# 1
# ##### List all cities where the area is greater than 5000, along with their population.

# %%
q  = '''SELECT c.name,f.area,c.population from cities c
INNER JOIN facts f 
ON 
c.facts_id = f.id
WHERE f.area > 5000
 '''
sql_query(q)
# Out:
#           name     area  population
# 0    Abu Dhabi    83600      942000
# 1        Dubai    83600     1978000
# 2      Sharjah    83600      983000
# 3        Kabul   652230     3097000
# 4      Algiers  2381741     2916000
# ..         ...      ...         ...
# 349    Mbabane    17364       66000
# 350      Sanaa   527968     2419000
# 351       Aden   527968      784000
# 352     Lusaka   752618     1802000
# 353     Harare   390757     1542000
#
# [354 rows x 3 columns]

# %% [markdown]
# ### Q # 2
# ##### List the names of capital cities where the death rate is greater than 2% and the birth rate is less than 20%

# %%
q  = '''SELECT c.name from cities c
INNER JOIN facts f 
ON 
c.facts_id = f.id
WHERE c.capital = 1   AND f.death_rate > 2   AND f.birth_rate < 20

 '''
sql_query(q)
# Out:
#                  name
# 0          Oranjestad
# 1        Saint John'S
# 2                Baku
# 3              Tirana
# 4             Yerevan
# ..                ...
# 123         Road Town
# 124             Hanoi
# 125  Charlotte Amalie
# 126          Windhoek
# 127          Mata-Utu
#
# [128 rows x 1 columns]

# %% [markdown]
# ### Q # 3
# ##### List the cities with a population growth rate between 1% and 5%, sorted in desc by population growth.

# %%
q  = '''select c.name, f.population_growth from cities c
inner join facts f ON c.facts_id = f.id
WHERE f.population_growth BETWEEN 1 AND 5
ORDER BY f.population_growth DESC


 '''
sql_query(q)
# Out:
#           name  population_growth
# 0         Juba               4.02
# 1     Lilongwe               3.32
# 2    Bujumbura               3.28
# 3       Niamey               3.25
# 4      Kampala               3.24
# ..         ...                ...
# 210        Fes               1.00
# 211  Marrakech               1.00
# 212    Tangier               1.00
# 213     Agadir               1.00
# 214    Managua               1.00
#
# [215 rows x 2 columns]

# %% [markdown]
# ### Q # 4
# ##### Find countries that start with &quot;A&quot; and do not have any cities listed in the cities table. The query should return the country name and city name. Using left join

# %%
q  = '''select f.name as country_name, c.name as city_name
FROM facts f
Left join cities c 
ON f.id = c.facts_id
WHERE f.name LIKE 'A%' AND c.name IS NULL

 '''
sql_query(q)
# Out:
#                   country_name city_name
# 0  Ashmore and Cartier Islands      None
# 1                     Akrotiri      None
# 2                   Antarctica      None
# 3                 Arctic Ocean      None
# 4               Atlantic Ocean      None

# %% [markdown]
# ### Q # 5
# ##### List all capital cities and their corresponding death rate using a LEFT JOIN.

# %%
q  = '''select c.name as capital_city, f.death_rate from cities c
LEFT JOIN facts f 
ON c.facts_id = f.id
WHERE c.capital = 1
 '''
sql_query(q)
# Out:
#      capital_city  death_rate
# 0      Oranjestad        8.18
# 1    Saint John'S        5.69
# 2       Abu Dhabi        1.97
# 3           Kabul       13.89
# 4         Algiers        4.31
# ..            ...         ...
# 203          Apia        5.32
# 204       Mbabane       13.56
# 205         Sanaa        6.28
# 206        Lusaka       12.67
# 207        Harare       10.13
#
# [208 rows x 2 columns]
